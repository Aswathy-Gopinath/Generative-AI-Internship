# %%
import pandas as pd

# %%
df = pd.read_csv("/content/titanic uncleaned.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0            892         0       3  ...    7.8292   NaN         Q
# 1            893         1       3  ...    7.0000   NaN         S
# 2            894         0       2  ...    9.6875   NaN         Q
# 3            895         0       3  ...    8.6625   NaN         S
# 4            896         1       3  ...   12.2875   NaN         S
# ..           ...       ...     ...  ...       ...   ...       ...
# 413         1305         0       3  ...    8.0500   NaN         S
# 414         1306         1       1  ...  108.9000  C105         C
# 415         1307         0       3  ...    7.2500   NaN         S
# 416         1308         0       3  ...    8.0500   NaN         S
# 417         1309         0       3  ...   22.3583   NaN         C
#
# [418 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0          892         0       3  ...   7.8292   NaN         Q
# 1          893         1       3  ...   7.0000   NaN         S
# 2          894         0       2  ...   9.6875   NaN         Q
# 3          895         0       3  ...   8.6625   NaN         S
# 4          896         1       3  ...  12.2875   NaN         S
#
# [5 rows x 12 columns]

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 413         1305         0       3  ...    8.0500   NaN         S
# 414         1306         1       1  ...  108.9000  C105         C
# 415         1307         0       3  ...    7.2500   NaN         S
# 416         1308         0       3  ...    8.0500   NaN         S
# 417         1309         0       3  ...   22.3583   NaN         C
#
# [5 rows x 12 columns]

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0          892         0       3  ...   7.8292   NaN         Q
# 1          893         1       3  ...   7.0000   NaN         S
# 2          894         0       2  ...   9.6875   NaN         Q
# 3          895         0       3  ...   8.6625   NaN         S
# 4          896         1       3  ...  12.2875   NaN         S
# 5          897         0       3  ...   9.2250   NaN         S
# 6          898         1       3  ...   7.6292   NaN         Q
# 7          899         0       2  ...  29.0000   NaN         S
# 8          900         1       3  ...   7.2292   NaN         C
# 9          901         0       3  ...  24.1500   NaN         S
#
# [10 rows x 12 columns]

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 408         1300         1       3  ...    7.7208   NaN         Q
# 409         1301         1       3  ...   13.7750   NaN         S
# 410         1302         1       3  ...    7.7500   NaN         Q
# 411         1303         1       1  ...   90.0000   C78         Q
# 412         1304         1       3  ...    7.7750   NaN         S
# 413         1305         0       3  ...    8.0500   NaN         S
# 414         1306         1       1  ...  108.9000  C105         C
# 415         1307         0       3  ...    7.2500   NaN         S
# 416         1308         0       3  ...    8.0500   NaN         S
# 417         1309         0       3  ...   22.3583   NaN         C
#
# [10 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.shape
# Out:
# (418, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   418.000000  418.000000  418.000000  ...  418.000000  418.000000  417.000000
# mean   1100.500000    0.363636    2.265550  ...    0.447368    0.392344   35.627188
# std     120.810458    0.481622    0.841838  ...    0.896760    0.981429   55.907576
# min     892.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     996.250000    0.000000    1.000000  ...    0.000000    0.000000    7.895800
# 50%    1100.500000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%    1204.750000    1.000000    3.000000  ...    1.000000    0.000000   31.500000
# max    1309.000000    1.000000    3.000000  ...    8.000000    9.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df[['PassengerId','Survived']]
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name  ...  Ticket   Fare  Cabin  Embarked
# 0          False     False   False  False  ...   False  False   True     False
# 1          False     False   False  False  ...   False  False   True     False
# 2          False     False   False  False  ...   False  False   True     False
# 3          False     False   False  False  ...   False  False   True     False
# 4          False     False   False  False  ...   False  False   True     False
# ..           ...       ...     ...    ...  ...     ...    ...    ...       ...
# 413        False     False   False  False  ...   False  False   True     False
# 414        False     False   False  False  ...   False  False  False     False
# 415        False     False   False  False  ...   False  False   True     False
# 416        False     False   False  False  ...   False  False   True     False
# 417        False     False   False  False  ...   False  False   True     False
#
# [418 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df['Age_mean_imputed'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Age_median_imputed'] = df['Age'].fillna(df['Age'].median())

# %%
df['Cabin_mode_imputed'] = df['Cabin'].fillna(df['Cabin'].mode()[0])

# %%
df[['Age','Age_mean_imputed']]
# Out:
#       Age  Age_mean_imputed
# 0    34.5          34.50000
# 1    47.0          47.00000
# 2    62.0          62.00000
# 3    27.0          27.00000
# 4    22.0          22.00000
# ..    ...               ...
# 413   NaN          30.27259
# 414  39.0          39.00000
# 415  38.5          38.50000
# 416   NaN          30.27259
# 417   NaN          30.27259
#
# [418 rows x 2 columns]

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x= 'Pclass', y ='Age', palette ='pastel')
plt.title('Boxplot of Age by Passenger Class',fontsize =16)
plt.xlabel('Passenger Class', fontsize =12)
plt.ylabel('Age',fontsize =12)
# Out:
# /tmp/ipykernel_1982/1490652332.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x= 'Pclass', y ='Age', palette ='pastel')
# Text(0, 0.5, 'Age')

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Pclass', hue='Survived', palette='pastel')

plt.title('Survival Count by Passenger Class', fontsize=16)
plt.xlabel('Passenger Class', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x= 'Embarked', y ='Fare', palette ='pastel')
plt.title('box plot of Fare values grouped by Embarked port.',fontsize =16)
plt.xlabel('Embarked', fontsize =12)
plt.ylabel('Fare',fontsize =12)
# Out:
# /tmp/ipykernel_1982/1793342947.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x= 'Embarked', y ='Fare', palette ='pastel')
# Text(0, 0.5, 'Fare')

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Pclass', hue='Survived', palette='pastel')

plt.title('Survived vs Dead by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Number of Passengers')
# Out:
# Text(0, 0.5, 'Number of Passengers')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoded_data = df.copy()

# %%
label_encoder = LabelEncoder()

# %%
encoded_data['Sex_Label'] = label_encoder.fit_transform(encoded_data['Sex'])

# %%
one_hot_encoded = pd.get_dummies(encoded_data['Embarked'],prefix ='Embarked')
encoded_data = pd.concat([encoded_data,one_hot_encoded],axis = 1)

# %%
pclass_mapping = {1: 'First', 2: 'Second', 3: 'Third'}

# %%
encoded_data['Pclass_Category'] = encoded_data['Pclass'].map(pclass_mapping)

# %%
print(encoded_data[['Sex', 'Sex_Label', 'Embarked', 'Embarked_Q', 'Embarked_S', 'Embarked_C', 'Pclass', 'Pclass_Category']].head())
# Out:
#       Sex  Sex_Label Embarked  ...  Embarked_C  Pclass  Pclass_Category
# 0    male          1        Q  ...       False       3            Third
# 1  female          0        S  ...       False       3            Third
# 2    male          1        Q  ...       False       2           Second
# 3    male          1        S  ...       False       3            Third
# 4  female          0        S  ...       False       3            Third
#
# [5 rows x 8 columns]

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
File_path = '/content/titanic uncleaned.csv'
titanic_data = pd.read_csv('/content/titanic uncleaned.csv')

# %%
minmax_scaler = MinMaxScaler()
standard_scaler = StandardScaler()
titanic_data['Age_MinMax'] = minmax_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Fare_MinMax'] = minmax_scaler.fit_transform(titanic_data[['Fare']])
titanic_data['Age_Standard'] = standard_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Fare_Standard'] = standard_scaler.fit_transform(titanic_data[['Fare']])

# %%
titanic_data[['Age','Age_MinMax','Age_Standard',
              'Fare','Fare_MinMax','Fare_Standard']].head()
# Out:
#     Age  Age_MinMax  Age_Standard     Fare  Fare_MinMax  Fare_Standard
# 0  34.5    0.452723      0.298549   7.8292     0.015282      -0.497811
# 1  47.0    0.617566      1.181328   7.0000     0.013663      -0.512660
# 2  62.0    0.815377      2.240662   9.6875     0.018909      -0.464532
# 3  27.0    0.353818     -0.231118   8.6625     0.016908      -0.482888
# 4  22.0    0.287881     -0.584229  12.2875     0.023984      -0.417971

# %%
print(titanic_data.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Age_MinMax',
#        'Fare_MinMax', 'Age_Standard'],
#       dtype='object')
